# %%
import numpy as np
from matplotlib import pyplot as plt
from kafe2 import  XYContainer, Fit, XYFit, Plot, ContoursProfiler                            
import PhyPraKit as ppk
from scipy.signal import find_peaks
from uncertainties import ufloat, unumpy
from math import log10, floor
import scipy.integrate as integrate
# Out:
# Welcome to JupyROOT 6.24/06

# %%
data = np.genfromtxt( "Aufgabe1.1.txt", #Daten einlesen
                      skip_header=3)
r = data[:,0]     # Daten Variablen zuweisen
l1 = data[:,1]     
l2 = data[:,2]
l3 = data[:,3]

# %%
print(l1)
# Out:
# [125. 120. 107. 104.  55.  45.]

# %%
l1=l1-18
l2=l2-18
l3=l3-18
print(l1,l2,l3)
# Out:
# [107. 102.  89.  86.  37.  27.] [102.  67.  47.  32.  24.  17.] [59. 36. 24. 21. 17. 12.]

# %%
a=[.1,.2,.3]
r0=[l1[0],l2[0],l3[0]]
r1=[l1[1],l2[1],l3[1]]
r2=[l1[2],l2[2],l3[2]]
r3=[l1[3],l2[3],l3[3]]
r4=[l1[4],l2[4],l3[4]]
r5=[l1[5],l2[5],l3[5]]
print(a,r0,r1,r2,r3,r4,r5)
# Out:
# [0.1, 0.2, 0.3] [107.0, 102.0, 59.0] [102.0, 67.0, 36.0] [89.0, 47.0, 24.0] [86.0, 32.0, 21.0] [37.0, 24.0, 17.0] [27.0, 17.0, 12.0]

# %%
plt.plot(a,r0,label='Radius r=0m',color='black',marker='.')
plt.plot(a,r1,label='Radius r=0.1m',color='red',marker='.')
plt.plot(a,r2,label='Radius r=0.2m',color='blue',marker='.')
plt.plot(a,r3,label='Radius r=0.3m',color='yellow',marker='.')
plt.plot(a,r4,label='Radius r=0.4m',color='purple',marker='.')
plt.plot(a,r5,label='Radius r=0.5m',color='darkblue',marker='.')
plt.legend(loc='best')
plt.xlabel('Abstand zum Winderzeuger in m')
plt.ylabel('P in Pa')
plt.savefig('Aufgabe1_1.png')
plt.show()

# %%
#1.2
data = np.genfromtxt( "Aufgabe1.2.txt", #Daten einlesen
                      skip_header=3)
U = data[:,0]     # Daten Variablen zuweisen
P = data[:,1]

# %%
P=P-18
print(P)
print(U)
xy_data = XYContainer(U,P)
print(xy_data)
# Out:
# [ 0.  4. 10. 17. 24. 34. 43. 56. 67. 82. 97.]
# [ 600.  800. 1000. 1200. 1400. 1600. 1800. 2000. 2200. 2400. 2600.]
# <kafe2.fit.xy.container.XYContainer object at 0x7f70105b6820>

# %%
def quad(x,a=0,c=0):
    return a*x**2 +c 


line_fit=Fit(data=xy_data,model_function=quad)
line_fit.do_fit()
#line_fit.assign_parameter_names(x='r', a='a', b='U/I^2')
#line_fit.assign_model_function_expression('B')
#line_fit.assign_model_function_expression("{a} * {x} ")
line_fit.report()

#line_fit.assign_parameter_latex_names(x='r', a='a', b='\frac{U}{I^2}')
#line_fit.assign_model_function_latex_name('\frac{U}{I^2}')
#line_fit.assign_model_function_latex_expression('{a} \\cdot {x}')


line_fit.data_container.label = "Verwendete Daten"
line_fit.model_label = "Modellfunktion"

line_fit.data_container.axis_labels = [ "c^2/2*r^2 in N*m/A^2","U/I^2 in V/A^2"]

plot = Plot(fit_objects=line_fit)
plot.plot()
plot.show()
plot.save()
print(xy_data)
# Out:
# ########
# # Data #
# ########
#
#     X Data
#     ======
#     600.0
#     800.0
#     1000.0
#     1200.0
#     1400.0
#     1600.0
#     1800.0
#     2000.0
#     2200.0
#     2400.0
#     2600.0
#
#     Y Data
#     ======
#     0.0
#     4.0
#     10.0
#     17.0
#     24.0
#     34.0
#     43.0
#     56.0
#     67.0
#     82.0
#     97.0
#
# #########
# # Model #
# #########
#
#     Model Function
#     ==============
#
#         quad(x; a, c)
#
#     X Model
#     =======
#     600.0
#     800.0
#     1000.0
#     1200.0
#     1400.0
#     1600.0
#     1800.0
#     2000.0
#     2200.0
#     2400.0
#     2600.0
#
#     Y Model
#     =======
#     0.136
#     4.37
#     9.814
#     16.47
#     24.33
#     33.41
#     43.69
#     55.18
#     67.88
#     81.8
#     96.92
#
# ###############
# # Fit Results #
# ###############
#
#     Model Parameters
#     ================
#
#         a = 1.5e-05
#         c = -5.3
#
#     Cost Function
#     =============
#
#         Cost function: chi-square (no uncertainties)
#
#         Cost = 2.91
# /opt/conda/lib/python3.9/site-packages/kafe2/fit/_base/fit.py:1036: UserWarning: No data/model errors were specified. Parameter errors cannot be calculated.
#   warnings.warn(
# <kafe2.fit.xy.container.XYContainer object at 0x7f70105b6820>

# %%
#Aufgabe 3
data = np.genfromtxt( "Aufgabe3.1.txt", #Daten einlesen
                      skip_header=3)
a = data[:,0]     # Daten Variablen zuweisen
auftrieb = data[:,1]
widerstand =data[:,2]
widerstand = widerstand - 0.02
xy_data = XYContainer(a,auftrieb)
xy_data2 = XYContainer(a,widerstand)
def linear(x,m=1,b=0):
    return m*x+b



line_fit=Fit(data=xy_data,model_function=linear)
line_fit.do_fit()

line_fit.data_container.label = "Verwendete Daten"
line_fit.model_label = "Modellfunktion der Auftriebskraft"

line_fit.data_container.axis_labels = ["Aufstellwinkel in Grad","Kraft in N"]

def quad(x,m=1,b=0):
    return m*x**2 +b

quad_fit=Fit(data=xy_data2,model_function=quad)
quad_fit.do_fit()

quad_fit.data_container.label = "Verwendete Daten"
quad_fit.model_label = "Modellfunktion des Strömungswiderstandes"

quad_fit.data_container.axis_labels = ["Aufstellwinkel in Grad","Kraft in N"]
plot = Plot(fit_objects=[quad_fit,line_fit])
plot.customize('data','color',[(0,'orange'),(1,'blue')])
plot.plot()
plot.save('Fit3_1.png')
# Out:
# /opt/conda/lib/python3.9/site-packages/kafe2/fit/_base/fit.py:1036: UserWarning: No data/model errors were specified. Parameter errors cannot be calculated.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/kafe2/fit/_base/fit.py:1036: UserWarning: No data/model errors were specified. Parameter errors cannot be calculated.
#   warnings.warn(

# %%
plt.plot(widerstand,auftrieb,'x')
plt.plot([0,widerstand[4]],[0,auftrieb[4]])
