# %%
import numpy as np
from matplotlib import pyplot as plt
from kafe2 import  XYContainer, Fit, XYFit, Plot, ContoursProfiler                            
import PhyPraKit as ppk
import scipy.signal as sp 
from uncertainties import ufloat, unumpy
from math import log10, floor
import scipy.integrate as integrate
import pandas as pd
# Out:
# Welcome to JupyROOT 6.24/06

# %%
data=pd.read_csv('Aufgabe 4 5v,200mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t5v200mA','s5v200mA','U5v200mA']
t5v200mA = data['t5v200mA'].to_numpy()
s5v200mA = data['s5v200mA'].to_numpy()
U5v200mA = data['U5v200mA'].to_numpy()
U5v200mA = U5v200mA[1:-1]
s5v200mA = s5v200mA[1:-1]
t5v200mA = t5v200mA[1:-1]
U5v200mA = U5v200mA-np.mean(U5v200mA)
U5v200mA = U5v200mA-np.mean(U5v200mA)
#freq, amp = ppk.Fourier_fft(t5v200mA, s5v200mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

data=pd.read_csv('Aufgabe 4 6v,200mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t6v200mA','s6v200mA','U6v200mA']
t6v200mA = data['t6v200mA'].to_numpy()
s6v200mA = data['s6v200mA'].to_numpy()
U6v200mA = data['U6v200mA'].to_numpy()
U6v200mA = U6v200mA[1:-1]
s6v200mA = s6v200mA[1:-1]
t6v200mA = t6v200mA[1:-1]
U6v200mA = U6v200mA-np.mean(U6v200mA)
#freq, amp = ppk.Fourier_fft(t6v200mA, s6v200mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

data=pd.read_csv('Aufgabe 4 7v,200mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t7v200mA','s7v200mA','U7v200mA']
t7v200mA = data['t7v200mA'].to_numpy()
s7v200mA = data['s7v200mA'].to_numpy()
U7v200mA = data['U7v200mA'].to_numpy()
U7v200mA = U7v200mA[1:-1]
s7v200mA = s7v200mA[1:-1]
t7v200mA = t7v200mA[1:-1]
U7v200mA = U7v200mA-np.mean(U7v200mA)
#freq, amp = ppk.Fourier_fft(t7v200mA, s7v200mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

data=pd.read_csv('Aufgabe 4 8v,200mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t8v200mA','s8v200mA','U8v200mA']
t8v200mA = data['t8v200mA'].to_numpy()
s8v200mA = data['s8v200mA'].to_numpy()
U8v200mA = data['U8v200mA'].to_numpy()
U8v200mA = U8v200mA[1:-1]
s8v200mA = s8v200mA[1:-1]
t8v200mA = t8v200mA[1:-1]
U8v200mA = U8v200mA-np.mean(U8v200mA)
#freq, amp = ppk.Fourier_fft(t8v200mA, s8v200mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

data=pd.read_csv('Aufgabe 4 6,5v,200mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t6_5v200mA','s6_5v200mA','U6_5v200mA']
t6_5v200mA = data['t6_5v200mA'].to_numpy()
s6_5v200mA = data['s6_5v200mA'].to_numpy()
U6_5v200mA = data['U6_5v200mA'].to_numpy()
U6_5v200mA = U6_5v200mA[1:-1]
s6_5v200mA = s6_5v200mA[1:-1]
t6_5v200mA = t6_5v200mA[1:-1]
U6_5v200mA = U6_5v200mA-np.mean(U6_5v200mA)
#freq, amp = ppk.Fourier_fft(t6_5v200mA, s6_5v200mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

# %%
data=pd.read_csv('Aufgabe 4 5v,400mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t5v400mA','s5v400mA','U5v400mA']
t5v400mA = data['t5v400mA'].to_numpy()
s5v400mA = data['s5v400mA'].to_numpy()
U5v400mA = data['U5v400mA'].to_numpy()
U5v400mA = U5v400mA[1:-1]
s5v400mA = s5v400mA[1:-1]
t5v400mA = t5v400mA[1:-1]
U5v400mA = U5v400mA-np.mean(U5v400mA)
#freq, amp = ppk.Fourier_fft(t5v400mA, s5v400mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)


data=pd.read_csv('Aufgabe 4 6v,400mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t6v400mA','s6v400mA','U6v400mA']
t6v400mA = data['t6v400mA'].to_numpy()
s6v400mA = data['s6v400mA'].to_numpy()
U6v400mA = data['U6v400mA'].to_numpy()
U6v400mA = U6v400mA[1:-1]
s6v400mA = s6v400mA[1:-1]
t6v400mA = t6v400mA[1:-1]
U6v400mA = U6v400mA-np.mean(U6v400mA)
#freq, amp = ppk.Fourier_fft(t6v400mA, s6v400mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
##plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)


data=pd.read_csv('Aufgabe 4 7v,400mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t7v400mA','s7v400mA','U7v400mA']
t7v400mA = data['t7v400mA'].to_numpy()
s7v400mA = data['s7v400mA'].to_numpy()
U7v400mA = data['U7v400mA'].to_numpy()
U7v400mA = U7v400mA[1:-1]
s7v400mA = s7v400mA[1:-1]
t7v400mA = t7v400mA[1:-1]
U7v400mA = U7v400mA-np.mean(U7v400mA)
#freq, amp = ppk.Fourier_fft(t7v400mA, s7v400mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
#plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)


data=pd.read_csv('Aufgabe 4 8v,400mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t8v400mA','s8v400mA','U8v400mA']
t8v400mA = data['t8v400mA'].to_numpy()
s8v400mA = data['s8v400mA'].to_numpy()
U8v400mA = data['U8v400mA'].to_numpy()
U8v400mA = U8v400mA[1:-1]
s8v400mA = s8v400mA[1:-1]
t8v400mA = t8v400mA[1:-1]
U8v400mA = U8v400mA-np.mean(U8v400mA)
#freq, amp = ppk.Fourier_fft(t8v400mA, s8v400mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
#plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)


data=pd.read_csv('Aufgabe 4 6.5v,400mA.txt',delimiter='\t',decimal=",",skiprows=1) #importiere Daten
data.columns=['t6_5v400mA','s6_5v400mA','U6_5v400mA']
t6_5v400mA = data['t6_5v400mA'].to_numpy()
s6_5v400mA = data['s6_5v400mA'].to_numpy()
U6_5v400mA = data['U6_5v400mA'].to_numpy()
U6_5v400mA = U6_5v400mA-np.mean(U6_5v400mA)
U6_5v400mA = U6_5v400mA[1:-1]
s6_5v400mA = s6_5v400mA[1:-1]
t6_5v400mA = t6_5v400mA[1:-1]
U6_5v400mA = U6_5v400mA-np.mean(U6_5v400mA)
#freq, amp = ppk.Fourier_fft(t6_5v400mA, s6_5v400mA)
#plt.figure(figsize=(10, 6), dpi=80)
#plt.plot(freq, amp, c='black', lw=1)
#plt.xlabel('Frequenz [Hz]')
#plt.ylabel('Amplitude')
#plt.savefig( 'fft_ppk.pdf', bbox_inches='tight' ) 
#frequency = freq[np.where(amp>0.15)]
#print(" --> Frequenz mit max. Amplitude: ", frequency)

# %%
xy_data = XYContainer(t6_5v400mA,s6_5v400mA)
def cosfit(t, x=1, w=3.306939635357677, phi=10):
    return w * np.sin(x*t + phi) 
line_fit=Fit(data=xy_data,model_function=cosfit)
#line_fit.add_error('y',0.05)
#line_fit.add_error('x',0.05)
line_fit.do_fit()
line_fit.data_container.label = "Verwendete Daten"
line_fit.model_label = "Modellfunktion"

plot = Plot(fit_objects=line_fit)
plot.plot()
# Out:
# /opt/conda/lib/python3.9/site-packages/kafe2/fit/_base/fit.py:1036: UserWarning: No data/model errors were specified. Parameter errors cannot be calculated.
#   warnings.warn(
# [{'main': {'plots': [{'type': 'data',
#      'fit_index': 0,
#      'adapter': <kafe2.fit.xy.plot.XYPlotAdapter at 0x7f0943c9e460>,
#      'artist': <ErrorbarContainer object of 3 artists>},
#     {'type': 'model',
#      'fit_index': 0,
#      'adapter': <kafe2.fit.xy.plot.XYPlotAdapter at 0x7f0943c9e460>,
#      'artist': None},
#     {'type': 'model_line',
#      'fit_index': 0,
#      'adapter': <kafe2.fit.xy.plot.XYPlotAdapter at 0x7f0943c9e460>,
#      'artist': [<matplotlib.lines.Line2D at 0x7f0943bbef40>]},
#     {'type': 'model_error_band',
#      'fit_index': 0,
#      'adapter': <kafe2.fit.xy.plot.XYPlotAdapter at 0x7f0943c9e460>,
#      'artist': None}],
#    'x_range': (-3.6899999999999977, 81.89)}}]

# %%
plt.plot(t6_5v400mA,s6_5v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
plt.plot(t6_5v400mA,1.9*np.sin(2/1.895*np.pi*t6_5v400mA))
x = np.where(s6_5v400mA>1.8999)
x
# Out:
# (array([  4,  22,  23,  41,  42,  60,  61,  79,  80,  98,  99, 117, 118,
#         136, 137, 155, 174, 175, 193, 212, 230, 231, 250, 269, 288, 306,
#         307, 326, 344, 363, 364, 382, 383, 401, 420, 439, 458, 477, 495,
#         496, 514, 515, 534, 552, 553, 571, 572, 590, 591, 609, 610, 628,
#         629, 647, 666, 685, 703, 704, 722, 723, 741, 742, 760, 761]),)

# %%
#plt.plot(t6_5v400mA,s6_5v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t6_5v400mA,1.9*np.sin(2/1.895*np.pi*t6_5v400mA + np.pi/2))
plt.plot(t6_5v400mA, -1.9*1.895/2*np.pi*np.cos(2/1.895*np.pi*t6_5v400mA + np.pi/2))
plt.plot(t6_5v400mA,U6_5v400mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('6_5v400mA.png')
plt.show()

# %%
peaks= sp.find_peaks(s6_5v400mA)
print(peaks)
print(len(peaks[0]))
t_mess=np.zeros(len(peaks[0]))
i=0
currenttime=0
for peak in peaks[0]:
    if(i>0 &i<len(peaks)-1):
        #plt.vlines(t[peak], -3, 3, color='red', ls='--',linewidth=0.6)
        t_mess[i-1]=s6_5v400mA[peak].copy()-currenttime
    i=i+1
    currenttime=s6_5v400mA[peak].copy()
    
    

print('Mittelwert Periodendauer:',np.mean(currenttime))
# Out:
# (array([  4,  22,  41,  60,  79,  98, 117, 136, 155, 174, 193, 212, 230,
#        250, 269, 288, 306, 326, 344, 363, 382, 401, 420, 439, 458, 477,
#        495, 514, 534, 552, 571, 590, 609, 628, 647, 666, 685, 703, 722,
#        741, 760]), {})
# 41
# Mittelwert Periodendauer: 1.9

# %%
#plt.plot(t5v200mA,s5v200mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t5v200mA,0.4*np.sin(2/2.45*np.pi*t5v200mA+np.pi/2))
plt.plot(t5v200mA, -0.4*2.45/2*np.pi*np.cos(2/2.45*np.pi*t5v200mA + np.pi/2))
plt.plot(t5v200mA,U5v200mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('5v200mA.png')
plt.show()

# %%
#plt.plot(t5v400mA,s5v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t5v400mA,0.4*np.sin(2/2.6*np.pi*t5v400mA +np.pi/2))
plt.plot(t5v400mA, -0.4*2.6/2*np.pi*np.cos(2/2.6*np.pi*t5v400mA + np.pi/2))
plt.plot(t5v400mA,U5v400mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('5v400mA.png')
plt.show()

# %%
#plt.plot(t6_5v200mA,s6_5v200mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t6_5v200mA,6.3*np.sin(2/1.85*np.pi*t6_5v200mA +np.pi/2))
plt.plot(t6_5v200mA, -6.3*1.85/2*np.pi*np.cos(2/1.85*np.pi*t6_5v200mA + np.pi/2))
plt.plot(t6_5v200mA,U6_5v200mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('6_5v200mA.png')
plt.show()

# %%
#plt.plot(t6v200mA,s6v200mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t6v200mA,1.1*np.sin(2/2.07*np.pi*t6v200mA + np.pi/2))
plt.plot(t6v200mA, -1.1*2.07/2*np.pi*np.cos(2/2.07*np.pi*t6v200mA + np.pi/2))
plt.plot(t6v200mA,U6v200mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('6v200mA.png')
plt.show()

# %%
#plt.plot(t6v400mA,s6v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t6v400mA,-1.0*np.sin(2/2.03*np.pi*t6v400mA ))
plt.plot(t6v400mA, -1*2.03/2*np.pi*np.cos(2/2.03*np.pi*t6v400mA + np.pi/2))
plt.plot(t6v400mA,U6v400mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('6v400mA.png')
plt.show()

# %%
#plt.plot(t7v200mA,s7v200mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t7v200mA,1.25*np.sin(2/1.73*np.pi*t7v200mA + np.pi/2))
plt.plot(t7v200mA, -1.25*1.73/2*np.pi*np.cos(2/1.73*np.pi*t7v200mA + np.pi/2))
plt.plot(t7v200mA,U7v200mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('7v200mA.png')
plt.show()

# %%
#plt.plot(t7v400mA,s7v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t7v400mA,-1*np.sin(2/1.75*np.pi*t7v400mA + np.pi/2))
plt.plot(t7v400mA, -1*1.75/2*np.pi*np.cos(2/1.75*np.pi*t7v400mA + np.pi/2))
plt.plot(t7v400mA,U7v400mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('7v400mA.png')
plt.show()

# %%
#plt.plot(t8v200mA,s8v200mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t8v200mA,0.4*np.sin(2/1.61*np.pi*t8v200mA + np.pi/2))
plt.plot(t8v200mA, -0.4*1.61/2*np.pi*np.cos(2/1.61*np.pi*t8v200mA + np.pi/2))
plt.plot(t8v200mA,U8v200mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad')
plt.savefig('8v200mA.png')
plt.show()

# %%
#plt.plot(t8v400mA,s8v400mA)
#plt.plot(t6_5v400mA,U6_5v400mA)
#plt.plot(t8v400mA,0.4*np.cos(2/1.5*np.pi*t8v400mA+np.pi/8))
plt.plot(t8v400mA, -0.4*1.5/2*np.pi*np.cos(2/1.5*np.pi*t8v400mA + np.pi/2))
plt.plot(t8v400mA,U8v400mA)
plt.xlabel('t in s')
plt.ylabel('Φ in rad, ')
plt.savefig('8v400mA.png')
plt.show()
